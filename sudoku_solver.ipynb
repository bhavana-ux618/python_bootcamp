# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavana-ux618/ai-bootcamp/blob/main/sudoku_solver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Your Sudoku Solver project is a great example of using **Object-Oriented Programming (OOP)** and **backtracking algorithms** in Python. It simulates how a real Sudoku solver works step by step.

Here’s a breakdown of your project:

---

# 🧩 Sudoku Solver Project

This project solves a Sudoku puzzle automatically using Python.

A Sudoku board is represented as a **9×9 grid**, where:

* Numbers `1–9` are fixed values
* `0` represents an empty cell

Your program:

1. Finds an empty cell
2. Tries numbers `1–9`
3. Checks if the number is valid
4. Continues recursively until the puzzle is solved

---

# 🏗️ Class Structure

You created a class called:

```python
class Board:
```

This class stores the Sudoku board and contains all the methods needed to solve it.

This is good OOP design because:

* Data (`board`) and behavior (`solver`, validation methods) are grouped together
* The code becomes organized and reusable

---

# 🔹 `__init__()` Method

```python
def __init__(self, board):
    self.board = board
```

This constructor initializes the Sudoku board.

When you create:

```python
gameboard = Board(board)
```

the puzzle is stored inside the object as:

```python
self.board
```

---

# 🔹 `__str__()` Method

```python
def __str__(self):
```

This method controls how the board is printed.

You replace zeros with `*`:

```python
row_str = [str(i) if i else '*' for i in row]
```

So empty spaces appear visually cleaner.

Example:

```text
* * 2 * * 8 * * *
```

instead of:

```text
0 0 2 0 0 8 0 0 0
```

Nice touch for readability 👍

---

# 🔍 Finding Empty Cells

```python
def find_empty_cell(self):
```

This method searches the board for a `0`.

```python
col = contents.index(0)
```

returns the first empty position.

If no empty cell exists:

```python
return None
```

which means the puzzle is complete.

---

# ✅ Validation Methods

You separated validation into 3 methods:

## 1. Check Row

```python
def valid_in_row(self, row, num):
```

Checks whether a number already exists in the row.

---

## 2. Check Column

```python
def valid_in_col(self, col, num):
```

Uses:

```python
all(...)
```

to ensure the number does not exist in the column.

---

## 3. Check 3×3 Square

```python
def valid_in_square(self, row, col, num):
```

This is one of the most important Sudoku rules.

You calculate the top-left corner of the square:

```python
row_start = (row // 3) * 3
col_start = (col // 3) * 3
```

Example:

* If row = 5
* `5 // 3 = 1`
* `1 * 3 = 3`

So the square starts at row index `3`.

Very efficient logic 👏

---

# 🔐 Combined Validation

```python
def is_valid(self, empty, num):
```

This combines all three checks:

```python
return all([valid_in_row, valid_in_col, valid_in_square])
```

A number is valid only if:

* not in row
* not in column
* not in square

---

# 🧠 Backtracking Algorithm

This is the heart of the project:

```python
def solver(self):
```

Your solver uses **recursive backtracking**.

---

## How Backtracking Works

### Step 1: Find an empty cell

```python
next_empty = self.find_empty_cell()
```

---

### Step 2: Try numbers 1–9

```python
for guess in range(1, 10):
```

---

### Step 3: Check validity

```python
if self.is_valid(next_empty, guess):
```

---

### Step 4: Place number

```python
self.board[row][col] = guess
```

---

### Step 5: Solve remaining puzzle recursively

```python
if self.solver():
    return True
```

---

### Step 6: Backtrack if wrong

```python
self.board[row][col] = 0
```

This removes incorrect guesses and tries another number.

That’s why it’s called **backtracking**.

---

# 🔁 Recursive Thinking

Your solver keeps calling itself:

```python
self.solver()
```

until:

* the puzzle is solved
* or all possibilities fail

This is a classic recursive AI/search technique.

---

# 🎯 Main Function

```python
def solve_sudoku(board):
```

This:

* creates a Board object
* prints the puzzle
* solves it
* prints the solution

Good separation of logic.

---

# 🧪 Puzzle Representation

```python
puzzle = [
  [0, 0, 2, ...]
]
```

Using nested lists is perfect because Sudoku is naturally a grid structure.

---

# 💡 Concepts Demonstrated

Your project demonstrates:

* ✅ Classes & Objects
* ✅ Constructors
* ✅ Special methods (`__str__`)
* ✅ Recursion
* ✅ Backtracking
* ✅ List comprehensions
* ✅ Exception handling
* ✅ Boolean logic
* ✅ Grid algorithms
* ✅ Problem solving

---

# 🚀 Why This Project Is Impressive

Sudoku solvers are popular interview and portfolio projects because they show:

* algorithmic thinking
* recursion skills
* clean logic
* optimization thinking

This is much more advanced than beginner Python scripts.

---

# 🔧 Possible Improvements

You could improve the project by adding:

## 🎨 Better Board Formatting

Add lines between 3×3 sections:

```text
5 3 | 0 0 7 | 0 0 0
------+-------+------
```

---

## ⚡ Speed Optimization

Use:

* Most constrained cell first
* Candidate tracking
* Constraint propagation

---

## 🖥️ GUI Version

Build a visual interface using:

* `tkinter`
* `pygame`
* or a web app

---

## 📂 Read Puzzles from File

Allow loading puzzles from:

* text files
* CSV
* JSON

---

# 🏆 Overall

This is a strong intermediate-level Python project that combines:

* clean OOP structure
* recursion
* algorithmic problem-solving
* real-world puzzle solving

You implemented the classic **Sudoku Backtracking Solver** very well 👏

# %%
class Board:
    def __init__(self, board):
        self.board = board

    def __str__(self):
        board_str = ''
        for row in self.board:
            row_str = [str(i) if i else '*' for i in row]
            board_str += ' '.join(row_str)
            board_str += '\n'
        return board_str

    def find_empty_cell(self):
        for row, contents in enumerate(self.board):
            try:
                col = contents.index(0)
                return row, col
            except ValueError:
                pass
        return None

    def valid_in_row(self, row, num):
        return num not in self.board[row]

    def valid_in_col(self, col, num):
        return all(self.board[row][col] != num for row in range(9))

    def valid_in_square(self, row, col, num):
        row_start = (row // 3) * 3
        col_start = (col // 3) * 3
        for row_no in range(row_start, row_start + 3):
            for col_no in range(col_start, col_start + 3):
                if self.board[row_no][col_no] == num:
                    return False
        return True

    def is_valid(self, empty, num):
        row, col = empty
        valid_in_row = self.valid_in_row(row, num)
        valid_in_col = self.valid_in_col(col, num)
        valid_in_square = self.valid_in_square(row, col, num)
        return all([valid_in_row, valid_in_col, valid_in_square])

    def solver(self):
        if (next_empty := self.find_empty_cell()) is None:
            return True
        for guess in range(1, 10):
            if self.is_valid(next_empty, guess):
                row, col = next_empty
                self.board[row][col] = guess
                if self.solver():
                    return True
                self.board[row][col] = 0
        return False

def solve_sudoku(board):
    gameboard = Board(board)
    print(f'Puzzle to solve:\n{gameboard}')
    if gameboard.solver():
        print(f'Solved puzzle:\n{gameboard}')
    else:
        print('The provided puzzle is unsolvable.')
    return gameboard

puzzle = [
  [0, 0, 2, 0, 0, 8, 0, 0, 0],
  [0, 0, 0, 0, 0, 3, 7, 6, 2],
  [4, 3, 0, 0, 0, 0, 8, 0, 0],
  [0, 5, 0, 0, 3, 0, 0, 9, 0],
  [0, 4, 0, 0, 0, 0, 0, 2, 6],
  [0, 0, 0, 4, 6, 7, 0, 0, 0],
  [0, 8, 6, 7, 0, 4, 0, 0, 0],
  [0, 0, 0, 5, 1, 9, 0, 0, 8],
  [1, 7, 0, 0, 0, 6, 0, 0, 5]
]
